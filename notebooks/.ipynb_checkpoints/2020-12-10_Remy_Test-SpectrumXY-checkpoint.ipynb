# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import numpy as np
import pandas as pd
import joblib
import sys
sys.path.append('../lib')
from utils import edf_loader, combiner, annotations_reader, find_breakpoints, find_sections,\
                    section_seiz, find_edf
from transformers import SpectrogramTransformer, SpectrumXY
from models import Baseline, PostProcessing
import time

# %%
np.array([[1,2,3]]) + np.array([[1,2,3]]).T
# Out:
# array([[2, 3, 4],
#        [3, 4, 5],
#        [4, 5, 6]])

# %% [markdown]
# # Run first part of pipeline

# %%
file = '../dataset/edf/train/01_tcp_ar/073/00007313/s001_2010_12_15/00007313_s001_t000.edf'
raw = edf_loader(file)
raw.info['montage_type'] = 1
tmax = raw.n_times/raw.info['sfreq']
wd = 8
S = SpectrogramTransformer(win_duration=wd)
t, f, spectrograms_db_list = S.fit_transform(raw)

# %%
transformer = SpectrumXY()
id_montage = 0
id_time = 3
spectrum = spectrograms_db_list[id_montage][:,id_time]
spectrumXY = transformer.fit_transform(spectrum)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(spectrumXY)

# %%
spectrumXY.shape
# Out:
# (801, 801)
